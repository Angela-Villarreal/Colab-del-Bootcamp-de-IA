# %% [markdown]
# <a href="https://colab.research.google.com/github/Angela-Villarreal/Colab-del-Bootcamp-de-IA/blob/main/Grafica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Datos: tamaño en m² y su precio en dólares

x = np.array([30, 50, 60, 80, 100]).reshape(-1, 1)  # tamaño (m²)
y = np.array([100000, 150000, 180000, 200000, 250000])  # precio

modelo = LinearRegression()
modelo.fit(x, y)

prediccion = modelo.predict(np.array([[70]]))  # predecimos precio para 70 m²
print("Precio estimado para 70 m²:", int(prediccion[0]), "USD")

plt.scatter(x, y, color='blue', label='Datos reales')  # puntos reales
plt.plot(x, modelo.predict(x), color='red', label='Línea de regresión')  # línea ajustada
plt.xlabel("Tamaño (m²)")
plt.ylabel("Precio (USD)")
plt.title("Regresión Lineal Simple")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Precio estimado para 70 m²: 188287 USD

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Simulamos 100 personas con experiencia entre 0 y 20 años
np.random.seed(0)  # para resultados reproducibles
experiencia = np.random.uniform(0, 20, 100).reshape(-1, 1)  # años de experiencia

# Ingreso mensual (base + experiencia * coeficiente + algo de ruido aleatorio)
ingreso = 20000 + experiencia * 3000 + np.random.normal(0, 5000, (100, 1))  # ingreso con ruido

modelo = LinearRegression()
modelo.fit(experiencia, ingreso)

ingreso_predicho = modelo.predict(experiencia)
plt.figure(figsize=(10, 6))
plt.scatter(experiencia, ingreso, color='skyblue', label='Datos reales')
plt.plot(experiencia, ingreso_predicho, color='red', linewidth=2, label='Línea de regresión')
plt.xlabel("Años de experiencia")
plt.ylabel("Ingreso mensual (USD)")
plt.title("Regresión lineal")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Simulamos 100 personas con experiencia entre 0 y 20 años
np.random.seed(0)  # para resultados reproducibles
experiencia = np.random.uniform(0, 20, 100).reshape(-1, 1)  # años de experiencia

# Ingreso mensual (base + experiencia * coeficiente + algo de ruido aleatorio)
ingreso = 20000 + experiencia * 3000 + np.random.normal(0, 5000, (100, 1))  # ingreso con ruido

modelo = LinearRegression()
modelo.fit(experiencia, ingreso)

ingreso_predicho = modelo.predict(experiencia)
plt.figure(figsize=(10, 6))
plt.scatter(experiencia, ingreso, color='skyblue', label='Datos reales')
plt.plot(experiencia, ingreso_predicho, color='red', linewidth=2, label='Línea de regresión')
plt.xlabel("Años de experiencia")
plt.ylabel("Ingreso mensual (USD)")
plt.title("Regresión lineal")
plt.legend()
plt.grid(True)
plt.show()

# ¿Cuánto ganaría una persona con 10 años de experiencia?
print("Ingreso estimado para 10 años de experiencia:", int(modelo.predict([[10]])[0][0]), "USD")
# Out:
# Ingreso estimado para 10 años de experiencia: 50953 USD
